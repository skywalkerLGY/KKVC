# %%
# coding=utf-8
import os
import re
import argparse
import utils
import commons
import json
import torch
import gradio as gr
from models import SynthesizerTrn
from text import text_to_sequence, _clean_text
from torch import no_grad, LongTensor
import gradio.processing_utils as gr_processing_utils
import logging
# Out:
# DEBUG:matplotlib:matplotlib data path: C:\Users\Skywalker\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\mpl-data
# DEBUG:matplotlib:CONFIGDIR=C:\Users\Skywalker\.matplotlib
# DEBUG:matplotlib:interactive is False
# DEBUG:matplotlib:platform is win32
# DEBUG:matplotlib:CACHEDIR=C:\Users\Skywalker\.matplotlib
# DEBUG:matplotlib.font_manager:Using fontManager instance from C:\Users\Skywalker\.matplotlib\fontlist-v330.json
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.gradio.app:443
# DEBUG:urllib3.connectionpool:https://api.gradio.app:443 "GET /gradio-messaging/en HTTP/1.1" 200 3
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=7)
#            2	LOAD_FAST(arg=0, lineno=7)
#            4	LOAD_ATTR(arg=0, lineno=7)
#            6	LOAD_CONST(arg=1, lineno=7)
#            8	BINARY_SUBSCR(arg=None, lineno=7)
#           10	STORE_FAST(arg=4, lineno=7)
#           12	LOAD_CONST(arg=2, lineno=8)
#           14	STORE_FAST(arg=5, lineno=8)
#           16	LOAD_GLOBAL(arg=1, lineno=9)
#           18	LOAD_GLOBAL(arg=2, lineno=9)
#           20	LOAD_FAST(arg=4, lineno=9)
#           22	CALL_FUNCTION(arg=1, lineno=9)
#           24	CALL_FUNCTION(arg=1, lineno=9)
#           26	GET_ITER(arg=None, lineno=9)
# >         28	FOR_ITER(arg=152, lineno=9)
#           30	STORE_FAST(arg=6, lineno=9)
#           32	LOAD_FAST(arg=0, lineno=10)
#           34	LOAD_FAST(arg=6, lineno=10)
#           36	BINARY_SUBSCR(arg=None, lineno=10)
#           38	STORE_FAST(arg=7, lineno=10)
#           40	LOAD_FAST(arg=1, lineno=11)
#           42	LOAD_FAST(arg=6, lineno=11)
#           44	BINARY_SUBSCR(arg=None, lineno=11)
#           46	STORE_FAST(arg=8, lineno=11)
#           48	LOAD_FAST(arg=2, lineno=12)
#           50	LOAD_FAST(arg=6, lineno=12)
#           52	BINARY_SUBSCR(arg=None, lineno=12)
#           54	STORE_FAST(arg=9, lineno=12)
#           56	LOAD_FAST(arg=3, lineno=13)
#           58	LOAD_FAST(arg=6, lineno=13)
#           60	BINARY_SUBSCR(arg=None, lineno=13)
#           62	STORE_FAST(arg=10, lineno=13)
#           64	LOAD_CONST(arg=3, lineno=15)
#           66	DUP_TOP(arg=None, lineno=15)
#           68	STORE_FAST(arg=11, lineno=15)
#           70	STORE_FAST(arg=12, lineno=15)
#           72	LOAD_FAST(arg=10, lineno=16)
#           74	LOAD_CONST(arg=4, lineno=16)
#           76	BINARY_SUBTRACT(arg=None, lineno=16)
#           78	STORE_FAST(arg=13, lineno=16)
#           80	LOAD_GLOBAL(arg=1, lineno=18)
#           82	LOAD_FAST(arg=9, lineno=18)
#           84	CALL_FUNCTION(arg=1, lineno=18)
#           86	GET_ITER(arg=None, lineno=18)
# >         88	FOR_ITER(arg=74, lineno=18)
#           90	STORE_FAST(arg=14, lineno=18)
#           92	LOAD_GLOBAL(arg=1, lineno=19)
#           94	LOAD_GLOBAL(arg=3, lineno=19)
#           96	LOAD_CONST(arg=1, lineno=19)
#           98	LOAD_FAST(arg=10, lineno=19)
#          100	LOAD_FAST(arg=14, lineno=19)
#          102	BINARY_ADD(arg=None, lineno=19)
#          104	LOAD_FAST(arg=9, lineno=19)
#          106	BINARY_SUBTRACT(arg=None, lineno=19)
#          108	CALL_FUNCTION(arg=2, lineno=19)
#          110	LOAD_GLOBAL(arg=4, lineno=19)
#          112	LOAD_FAST(arg=10, lineno=19)
#          114	LOAD_FAST(arg=14, lineno=19)
#          116	LOAD_CONST(arg=4, lineno=19)
#          118	BINARY_ADD(arg=None, lineno=19)
#          120	CALL_FUNCTION(arg=2, lineno=19)
#          122	CALL_FUNCTION(arg=2, lineno=19)
#          124	GET_ITER(arg=None, lineno=19)
# >        126	FOR_ITER(arg=54, lineno=19)
#          128	STORE_FAST(arg=15, lineno=19)
#          130	LOAD_FAST(arg=15, lineno=20)
#          132	LOAD_FAST(arg=14, lineno=20)
#          134	COMPARE_OP(arg=2, lineno=20)
#          136	POP_JUMP_IF_FALSE(arg=73, lineno=20)
#          138	LOAD_FAST(arg=5, lineno=21)
#          140	STORE_FAST(arg=12, lineno=21)
#          142	JUMP_FORWARD(arg=8, lineno=21)
# >        144	LOAD_FAST(arg=8, lineno=23)
#          146	LOAD_FAST(arg=14, lineno=23)
#          148	LOAD_CONST(arg=4, lineno=23)
#          150	BINARY_SUBTRACT(arg=None, lineno=23)
#          152	LOAD_FAST(arg=15, lineno=23)
#          154	BUILD_TUPLE(arg=2, lineno=23)
#          156	BINARY_SUBSCR(arg=None, lineno=23)
#          158	STORE_FAST(arg=12, lineno=23)
# >        160	LOAD_FAST(arg=15, lineno=24)
#          162	LOAD_CONST(arg=1, lineno=24)
#          164	COMPARE_OP(arg=2, lineno=24)
#          166	POP_JUMP_IF_FALSE(arg=95, lineno=24)
#          168	LOAD_FAST(arg=14, lineno=25)
#          170	LOAD_CONST(arg=1, lineno=25)
#          172	COMPARE_OP(arg=2, lineno=25)
#          174	POP_JUMP_IF_FALSE(arg=92, lineno=25)
#          176	LOAD_CONST(arg=3, lineno=26)
#          178	STORE_FAST(arg=11, lineno=26)
#          180	JUMP_FORWARD(arg=13, lineno=26)
# >        182	LOAD_FAST(arg=5, lineno=28)
#          184	STORE_FAST(arg=11, lineno=28)
#          186	JUMP_FORWARD(arg=10, lineno=28)
# >        188	LOAD_FAST(arg=8, lineno=30)
#          190	LOAD_FAST(arg=14, lineno=30)
#          192	LOAD_CONST(arg=4, lineno=30)
#          194	BINARY_SUBTRACT(arg=None, lineno=30)
#          196	LOAD_FAST(arg=15, lineno=30)
#          198	LOAD_CONST(arg=4, lineno=30)
#          200	BINARY_SUBTRACT(arg=None, lineno=30)
#          202	BUILD_TUPLE(arg=2, lineno=30)
#          204	BINARY_SUBSCR(arg=None, lineno=30)
#          206	STORE_FAST(arg=11, lineno=30)
# >        208	LOAD_FAST(arg=8, lineno=31)
#          210	LOAD_FAST(arg=14, lineno=31)
#          212	LOAD_FAST(arg=15, lineno=31)
#          214	BUILD_TUPLE(arg=2, lineno=31)
#          216	DUP_TOP_TWO(arg=None, lineno=31)
#          218	BINARY_SUBSCR(arg=None, lineno=31)
#          220	LOAD_GLOBAL(arg=3, lineno=31)
#          222	LOAD_FAST(arg=11, lineno=31)
#          224	LOAD_FAST(arg=12, lineno=31)
#          226	CALL_FUNCTION(arg=2, lineno=31)
#          228	INPLACE_ADD(arg=None, lineno=31)
#          230	ROT_THREE(arg=None, lineno=31)
#          232	STORE_SUBSCR(arg=None, lineno=31)
#          234	JUMP_ABSOLUTE(arg=64, lineno=31)
# >        236	JUMP_ABSOLUTE(arg=45, lineno=19)
# >        238	LOAD_GLOBAL(arg=1, lineno=33)
#          240	LOAD_FAST(arg=9, lineno=33)
#          242	LOAD_CONST(arg=4, lineno=33)
#          244	BINARY_SUBTRACT(arg=None, lineno=33)
#          246	LOAD_CONST(arg=5, lineno=33)
#          248	LOAD_CONST(arg=5, lineno=33)
#          250	CALL_FUNCTION(arg=3, lineno=33)
#          252	GET_ITER(arg=None, lineno=33)
# >        254	FOR_ITER(arg=38, lineno=33)
#          256	STORE_FAST(arg=14, lineno=33)
#          258	LOAD_CONST(arg=4, lineno=34)
#          260	LOAD_FAST(arg=7, lineno=34)
#          262	LOAD_FAST(arg=14, lineno=34)
#          264	LOAD_FAST(arg=13, lineno=34)
#          266	BUILD_TUPLE(arg=2, lineno=34)
#          268	STORE_SUBSCR(arg=None, lineno=34)
#          270	LOAD_FAST(arg=13, lineno=35)
#          272	LOAD_CONST(arg=1, lineno=35)
#          274	COMPARE_OP(arg=3, lineno=35)
#          276	POP_JUMP_IF_FALSE(arg=166, lineno=35)
#          278	LOAD_FAST(arg=13, lineno=35)
#          280	LOAD_FAST(arg=14, lineno=35)
#          282	COMPARE_OP(arg=2, lineno=35)
#          284	POP_JUMP_IF_TRUE(arg=162, lineno=35)
#          286	LOAD_FAST(arg=8, lineno=35)
#          288	LOAD_FAST(arg=14, lineno=35)
#          290	LOAD_CONST(arg=4, lineno=35)
#          292	BINARY_SUBTRACT(arg=None, lineno=35)
#          294	LOAD_FAST(arg=13, lineno=35)
#          296	BUILD_TUPLE(arg=2, lineno=35)
#          298	BINARY_SUBSCR(arg=None, lineno=35)
#          300	LOAD_FAST(arg=8, lineno=35)
#          302	LOAD_FAST(arg=14, lineno=35)
#          304	LOAD_CONST(arg=4, lineno=35)
#          306	BINARY_SUBTRACT(arg=None, lineno=35)
#          308	LOAD_FAST(arg=13, lineno=35)
#          310	LOAD_CONST(arg=4, lineno=35)
#          312	BINARY_SUBTRACT(arg=None, lineno=35)
#          314	BUILD_TUPLE(arg=2, lineno=35)
#          316	BINARY_SUBSCR(arg=None, lineno=35)
#          318	COMPARE_OP(arg=0, lineno=35)
#          320	POP_JUMP_IF_FALSE(arg=166, lineno=35)
# >        322	LOAD_FAST(arg=13, lineno=36)
#          324	LOAD_CONST(arg=4, lineno=36)
#          326	BINARY_SUBTRACT(arg=None, lineno=36)
#          328	STORE_FAST(arg=13, lineno=36)
# >        330	JUMP_ABSOLUTE(arg=128, lineno=36)
# >        332	JUMP_ABSOLUTE(arg=15, lineno=33)
# >        334	LOAD_CONST(arg=0, lineno=9)
#          336	RETURN_VALUE(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:dispatch pc=0, inst=NOP(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=2, inst=LOAD_FAST(arg=0, lineno=7)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=4, inst=LOAD_ATTR(arg=0, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$paths2.0']
# DEBUG:numba.core.byteflow:dispatch pc=6, inst=LOAD_CONST(arg=1, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$4load_attr.1']
# DEBUG:numba.core.byteflow:dispatch pc=8, inst=BINARY_SUBSCR(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$4load_attr.1', '$const6.2']
# DEBUG:numba.core.byteflow:dispatch pc=10, inst=STORE_FAST(arg=4, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$8binary_subscr.3']
# DEBUG:numba.core.byteflow:dispatch pc=12, inst=LOAD_CONST(arg=2, lineno=8)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=14, inst=STORE_FAST(arg=5, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$const12.4']
# DEBUG:numba.core.byteflow:dispatch pc=16, inst=LOAD_GLOBAL(arg=1, lineno=9)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=18, inst=LOAD_GLOBAL(arg=2, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$16load_global.5']
# DEBUG:numba.core.byteflow:dispatch pc=20, inst=LOAD_FAST(arg=4, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$16load_global.5', '$18load_global.6']
# DEBUG:numba.core.byteflow:dispatch pc=22, inst=CALL_FUNCTION(arg=1, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$16load_global.5', '$18load_global.6', '$b20.7']
# DEBUG:numba.core.byteflow:dispatch pc=24, inst=CALL_FUNCTION(arg=1, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$16load_global.5', '$22call_function.8']
# DEBUG:numba.core.byteflow:dispatch pc=26, inst=GET_ITER(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$24call_function.9']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=28, stack=('$26get_iter.10',), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=28 nstack_initial=1)])
# DEBUG:numba.core.byteflow:stack: ['$phi28.0']
# DEBUG:numba.core.byteflow:dispatch pc=28, inst=FOR_ITER(arg=152, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$phi28.0']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=334, stack=(), blockstack=(), npush=0), Edge(pc=30, stack=('$phi28.0', '$28for_iter.2'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=334 nstack_initial=0), State(pc_initial=30 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:dispatch pc=334, inst=LOAD_CONST(arg=0, lineno=9)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=336, inst=RETURN_VALUE(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$const334.0']
# DEBUG:numba.core.byteflow:end state. edges=[]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=30 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: ['$phi30.0', '$phi30.1']
# DEBUG:numba.core.byteflow:dispatch pc=30, inst=STORE_FAST(arg=6, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$phi30.0', '$phi30.1']
# DEBUG:numba.core.byteflow:dispatch pc=32, inst=LOAD_FAST(arg=0, lineno=10)
# DEBUG:numba.core.byteflow:stack ['$phi30.0']
# DEBUG:numba.core.byteflow:dispatch pc=34, inst=LOAD_FAST(arg=6, lineno=10)
# DEBUG:numba.core.byteflow:stack ['$phi30.0', '$paths32.2']
# DEBUG:numba.core.byteflow:dispatch pc=36, inst=BINARY_SUBSCR(arg=None, lineno=10)
# DEBUG:numba.core.byteflow:stack ['$phi30.0', '$paths32.2', '$i34.3']
# DEBUG:numba.core.byteflow:dispatch pc=38, inst=STORE_FAST(arg=7, lineno=10)
# DEBUG:numba.core.byteflow:stack ['$phi30.0', '$36binary_subscr.4']
# DEBUG:numba.core.byteflow:dispatch pc=40, inst=LOAD_FAST(arg=1, lineno=11)
# DEBUG:numba.core.byteflow:stack ['$phi30.0']
# DEBUG:numba.core.byteflow:dispatch pc=42, inst=LOAD_FAST(arg=6, lineno=11)
# DEBUG:numba.core.byteflow:stack ['$phi30.0', '$values40.5']
# DEBUG:numba.core.byteflow:dispatch pc=44, inst=BINARY_SUBSCR(arg=None, lineno=11)
# DEBUG:numba.core.byteflow:stack ['$phi30.0', '$values40.5', '$i42.6']
# DEBUG:numba.core.byteflow:dispatch pc=46, inst=STORE_FAST(arg=8, lineno=11)
# DEBUG:numba.core.byteflow:stack ['$phi30.0', '$44binary_subscr.7']
# DEBUG:numba.core.byteflow:dispatch pc=48, inst=LOAD_FAST(arg=2, lineno=12)
# DEBUG:numba.core.byteflow:stack ['$phi30.0']
# DEBUG:numba.core.byteflow:dispatch pc=50, inst=LOAD_FAST(arg=6, lineno=12)
# DEBUG:numba.core.byteflow:stack ['$phi30.0', '$t_ys48.8']
# DEBUG:numba.core.byteflow:dispatch pc=52, inst=BINARY_SUBSCR(arg=None, lineno=12)
# DEBUG:numba.core.byteflow:stack ['$phi30.0', '$t_ys48.8', '$i50.9']
# DEBUG:numba.core.byteflow:dispatch pc=54, inst=STORE_FAST(arg=9, lineno=12)
# DEBUG:numba.core.byteflow:stack ['$phi30.0', '$52binary_subscr.10']
# DEBUG:numba.core.byteflow:dispatch pc=56, inst=LOAD_FAST(arg=3, lineno=13)
# DEBUG:numba.core.byteflow:stack ['$phi30.0']
# DEBUG:numba.core.byteflow:dispatch pc=58, inst=LOAD_FAST(arg=6, lineno=13)
# DEBUG:numba.core.byteflow:stack ['$phi30.0', '$t_xs56.11']
# DEBUG:numba.core.byteflow:dispatch pc=60, inst=BINARY_SUBSCR(arg=None, lineno=13)
# DEBUG:numba.core.byteflow:stack ['$phi30.0', '$t_xs56.11', '$i58.12']
# DEBUG:numba.core.byteflow:dispatch pc=62, inst=STORE_FAST(arg=10, lineno=13)
# DEBUG:numba.core.byteflow:stack ['$phi30.0', '$60binary_subscr.13']
# DEBUG:numba.core.byteflow:dispatch pc=64, inst=LOAD_CONST(arg=3, lineno=15)
# DEBUG:numba.core.byteflow:stack ['$phi30.0']
# DEBUG:numba.core.byteflow:dispatch pc=66, inst=DUP_TOP(arg=None, lineno=15)
# DEBUG:numba.core.byteflow:stack ['$phi30.0', '$const64.14']
# DEBUG:numba.core.byteflow:dispatch pc=68, inst=STORE_FAST(arg=11, lineno=15)
# DEBUG:numba.core.byteflow:stack ['$phi30.0', '$const64.14', '$66dup_top.15']
# DEBUG:numba.core.byteflow:dispatch pc=70, inst=STORE_FAST(arg=12, lineno=15)
# DEBUG:numba.core.byteflow:stack ['$phi30.0', '$const64.14']
# DEBUG:numba.core.byteflow:dispatch pc=72, inst=LOAD_FAST(arg=10, lineno=16)
# DEBUG:numba.core.byteflow:stack ['$phi30.0']
# DEBUG:numba.core.byteflow:dispatch pc=74, inst=LOAD_CONST(arg=4, lineno=16)
# DEBUG:numba.core.byteflow:stack ['$phi30.0', '$t_x72.16']
# DEBUG:numba.core.byteflow:dispatch pc=76, inst=BINARY_SUBTRACT(arg=None, lineno=16)
# DEBUG:numba.core.byteflow:stack ['$phi30.0', '$t_x72.16', '$const74.17']
# DEBUG:numba.core.byteflow:dispatch pc=78, inst=STORE_FAST(arg=13, lineno=16)
# DEBUG:numba.core.byteflow:stack ['$phi30.0', '$76binary_subtract.18']
# DEBUG:numba.core.byteflow:dispatch pc=80, inst=LOAD_GLOBAL(arg=1, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi30.0']
# DEBUG:numba.core.byteflow:dispatch pc=82, inst=LOAD_FAST(arg=9, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi30.0', '$80load_global.19']
# DEBUG:numba.core.byteflow:dispatch pc=84, inst=CALL_FUNCTION(arg=1, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi30.0', '$80load_global.19', '$t_y82.20']
# DEBUG:numba.core.byteflow:dispatch pc=86, inst=GET_ITER(arg=None, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi30.0', '$84call_function.21']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=88, stack=('$phi30.0', '$86get_iter.22'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=88 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: ['$phi88.0', '$phi88.1']
# DEBUG:numba.core.byteflow:dispatch pc=88, inst=FOR_ITER(arg=74, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi88.0', '$phi88.1']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=238, stack=('$phi88.0',), blockstack=(), npush=0), Edge(pc=90, stack=('$phi88.0', '$phi88.1', '$88for_iter.3'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=238 nstack_initial=1), State(pc_initial=90 nstack_initial=3)])
# DEBUG:numba.core.byteflow:stack: ['$phi238.0']
# DEBUG:numba.core.byteflow:dispatch pc=238, inst=LOAD_GLOBAL(arg=1, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$phi238.0']
# DEBUG:numba.core.byteflow:dispatch pc=240, inst=LOAD_FAST(arg=9, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$phi238.0', '$238load_global.1']
# DEBUG:numba.core.byteflow:dispatch pc=242, inst=LOAD_CONST(arg=4, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$phi238.0', '$238load_global.1', '$t_y240.2']
# DEBUG:numba.core.byteflow:dispatch pc=244, inst=BINARY_SUBTRACT(arg=None, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$phi238.0', '$238load_global.1', '$t_y240.2', '$const242.3']
# DEBUG:numba.core.byteflow:dispatch pc=246, inst=LOAD_CONST(arg=5, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$phi238.0', '$238load_global.1', '$244binary_subtract.4']
# DEBUG:numba.core.byteflow:dispatch pc=248, inst=LOAD_CONST(arg=5, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$phi238.0', '$238load_global.1', '$244binary_subtract.4', '$const246.5']
# DEBUG:numba.core.byteflow:dispatch pc=250, inst=CALL_FUNCTION(arg=3, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$phi238.0', '$238load_global.1', '$244binary_subtract.4', '$const246.5', '$const248.6']
# DEBUG:numba.core.byteflow:dispatch pc=252, inst=GET_ITER(arg=None, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$phi238.0', '$250call_function.7']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=254, stack=('$phi238.0', '$252get_iter.8'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=90 nstack_initial=3), State(pc_initial=254 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: ['$phi90.0', '$phi90.1', '$phi90.2']
# DEBUG:numba.core.byteflow:dispatch pc=90, inst=STORE_FAST(arg=14, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi90.0', '$phi90.1', '$phi90.2']
# DEBUG:numba.core.byteflow:dispatch pc=92, inst=LOAD_GLOBAL(arg=1, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi90.0', '$phi90.1']
# DEBUG:numba.core.byteflow:dispatch pc=94, inst=LOAD_GLOBAL(arg=3, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi90.0', '$phi90.1', '$92load_global.3']
# DEBUG:numba.core.byteflow:dispatch pc=96, inst=LOAD_CONST(arg=1, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi90.0', '$phi90.1', '$92load_global.3', '$94load_global.4']
# DEBUG:numba.core.byteflow:dispatch pc=98, inst=LOAD_FAST(arg=10, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi90.0', '$phi90.1', '$92load_global.3', '$94load_global.4', '$const96.5']
# DEBUG:numba.core.byteflow:dispatch pc=100, inst=LOAD_FAST(arg=14, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi90.0', '$phi90.1', '$92load_global.3', '$94load_global.4', '$const96.5', '$t_x98.6']
# DEBUG:numba.core.byteflow:dispatch pc=102, inst=BINARY_ADD(arg=None, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi90.0', '$phi90.1', '$92load_global.3', '$94load_global.4', '$const96.5', '$t_x98.6', '$y100.7']
# DEBUG:numba.core.byteflow:dispatch pc=104, inst=LOAD_FAST(arg=9, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi90.0', '$phi90.1', '$92load_global.3', '$94load_global.4', '$const96.5', '$102binary_add.8']
# DEBUG:numba.core.byteflow:dispatch pc=106, inst=BINARY_SUBTRACT(arg=None, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi90.0', '$phi90.1', '$92load_global.3', '$94load_global.4', '$const96.5', '$102binary_add.8', '$t_y104.9']
# DEBUG:numba.core.byteflow:dispatch pc=108, inst=CALL_FUNCTION(arg=2, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi90.0', '$phi90.1', '$92load_global.3', '$94load_global.4', '$const96.5', '$106binary_subtract.10']
# DEBUG:numba.core.byteflow:dispatch pc=110, inst=LOAD_GLOBAL(arg=4, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi90.0', '$phi90.1', '$92load_global.3', '$108call_function.11']
# DEBUG:numba.core.byteflow:dispatch pc=112, inst=LOAD_FAST(arg=10, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi90.0', '$phi90.1', '$92load_global.3', '$108call_function.11', '$110load_global.12']
# DEBUG:numba.core.byteflow:dispatch pc=114, inst=LOAD_FAST(arg=14, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi90.0', '$phi90.1', '$92load_global.3', '$108call_function.11', '$110load_global.12', '$t_x112.13']
# DEBUG:numba.core.byteflow:dispatch pc=116, inst=LOAD_CONST(arg=4, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi90.0', '$phi90.1', '$92load_global.3', '$108call_function.11', '$110load_global.12', '$t_x112.13', '$y114.14']
# DEBUG:numba.core.byteflow:dispatch pc=118, inst=BINARY_ADD(arg=None, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi90.0', '$phi90.1', '$92load_global.3', '$108call_function.11', '$110load_global.12', '$t_x112.13', '$y114.14', '$const116.15']
# DEBUG:numba.core.byteflow:dispatch pc=120, inst=CALL_FUNCTION(arg=2, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi90.0', '$phi90.1', '$92load_global.3', '$108call_function.11', '$110load_global.12', '$t_x112.13', '$118binary_add.16']
# DEBUG:numba.core.byteflow:dispatch pc=122, inst=CALL_FUNCTION(arg=2, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi90.0', '$phi90.1', '$92load_global.3', '$108call_function.11', '$120call_function.17']
# DEBUG:numba.core.byteflow:dispatch pc=124, inst=GET_ITER(arg=None, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi90.0', '$phi90.1', '$122call_function.18']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=126, stack=('$phi90.0', '$phi90.1', '$124get_iter.19'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=254 nstack_initial=2), State(pc_initial=126 nstack_initial=3)])
# DEBUG:numba.core.byteflow:stack: ['$phi254.0', '$phi254.1']
# DEBUG:numba.core.byteflow:dispatch pc=254, inst=FOR_ITER(arg=38, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$phi254.0', '$phi254.1']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=332, stack=('$phi254.0',), blockstack=(), npush=0), Edge(pc=256, stack=('$phi254.0', '$phi254.1', '$254for_iter.3'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=126 nstack_initial=3), State(pc_initial=332 nstack_initial=1), State(pc_initial=256 nstack_initial=3)])
# DEBUG:numba.core.byteflow:stack: ['$phi126.0', '$phi126.1', '$phi126.2']
# DEBUG:numba.core.byteflow:dispatch pc=126, inst=FOR_ITER(arg=54, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi126.0', '$phi126.1', '$phi126.2']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=236, stack=('$phi126.0', '$phi126.1'), blockstack=(), npush=0), Edge(pc=128, stack=('$phi126.0', '$phi126.1', '$phi126.2', '$126for_iter.4'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=332 nstack_initial=1), State(pc_initial=256 nstack_initial=3), State(pc_initial=236 nstack_initial=2), State(pc_initial=128 nstack_initial=4)])
# DEBUG:numba.core.byteflow:stack: ['$phi332.0']
# DEBUG:numba.core.byteflow:dispatch pc=332, inst=JUMP_ABSOLUTE(arg=15, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$phi332.0']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=28, stack=('$phi332.0',), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=256 nstack_initial=3), State(pc_initial=236 nstack_initial=2), State(pc_initial=128 nstack_initial=4), State(pc_initial=28 nstack_initial=1)])
# DEBUG:numba.core.byteflow:stack: ['$phi256.0', '$phi256.1', '$phi256.2']
# DEBUG:numba.core.byteflow:dispatch pc=256, inst=STORE_FAST(arg=14, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$phi256.0', '$phi256.1', '$phi256.2']
# DEBUG:numba.core.byteflow:dispatch pc=258, inst=LOAD_CONST(arg=4, lineno=34)
# DEBUG:numba.core.byteflow:stack ['$phi256.0', '$phi256.1']
# DEBUG:numba.core.byteflow:dispatch pc=260, inst=LOAD_FAST(arg=7, lineno=34)
# DEBUG:numba.core.byteflow:stack ['$phi256.0', '$phi256.1', '$const258.3']
# DEBUG:numba.core.byteflow:dispatch pc=262, inst=LOAD_FAST(arg=14, lineno=34)
# DEBUG:numba.core.byteflow:stack ['$phi256.0', '$phi256.1', '$const258.3', '$path260.4']
# DEBUG:numba.core.byteflow:dispatch pc=264, inst=LOAD_FAST(arg=13, lineno=34)
# DEBUG:numba.core.byteflow:stack ['$phi256.0', '$phi256.1', '$const258.3', '$path260.4', '$y262.5']
# DEBUG:numba.core.byteflow:dispatch pc=266, inst=BUILD_TUPLE(arg=2, lineno=34)
# DEBUG:numba.core.byteflow:stack ['$phi256.0', '$phi256.1', '$const258.3', '$path260.4', '$y262.5', '$index264.6']
# DEBUG:numba.core.byteflow:dispatch pc=268, inst=STORE_SUBSCR(arg=None, lineno=34)
# DEBUG:numba.core.byteflow:stack ['$phi256.0', '$phi256.1', '$const258.3', '$path260.4', '$266build_tuple.7']
# DEBUG:numba.core.byteflow:dispatch pc=270, inst=LOAD_FAST(arg=13, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi256.0', '$phi256.1']
# DEBUG:numba.core.byteflow:dispatch pc=272, inst=LOAD_CONST(arg=1, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi256.0', '$phi256.1', '$index270.8']
# DEBUG:numba.core.byteflow:dispatch pc=274, inst=COMPARE_OP(arg=3, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi256.0', '$phi256.1', '$index270.8', '$const272.9']
# DEBUG:numba.core.byteflow:dispatch pc=276, inst=POP_JUMP_IF_FALSE(arg=166, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi256.0', '$phi256.1', '$274compare_op.10']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=278, stack=('$phi256.0', '$phi256.1'), blockstack=(), npush=0), Edge(pc=330, stack=('$phi256.0', '$phi256.1'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=236 nstack_initial=2), State(pc_initial=128 nstack_initial=4), State(pc_initial=28 nstack_initial=1), State(pc_initial=278 nstack_initial=2), State(pc_initial=330 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: ['$phi236.0', '$phi236.1']
# DEBUG:numba.core.byteflow:dispatch pc=236, inst=JUMP_ABSOLUTE(arg=45, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi236.0', '$phi236.1']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=88, stack=('$phi236.0', '$phi236.1'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=128 nstack_initial=4), State(pc_initial=28 nstack_initial=1), State(pc_initial=278 nstack_initial=2), State(pc_initial=330 nstack_initial=2), State(pc_initial=88 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: ['$phi128.0', '$phi128.1', '$phi128.2', '$phi128.3']
# DEBUG:numba.core.byteflow:dispatch pc=128, inst=STORE_FAST(arg=15, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi128.0', '$phi128.1', '$phi128.2', '$phi128.3']
# DEBUG:numba.core.byteflow:dispatch pc=130, inst=LOAD_FAST(arg=15, lineno=20)
# DEBUG:numba.core.byteflow:stack ['$phi128.0', '$phi128.1', '$phi128.2']
# DEBUG:numba.core.byteflow:dispatch pc=132, inst=LOAD_FAST(arg=14, lineno=20)
# DEBUG:numba.core.byteflow:stack ['$phi128.0', '$phi128.1', '$phi128.2', '$x130.4']
# DEBUG:numba.core.byteflow:dispatch pc=134, inst=COMPARE_OP(arg=2, lineno=20)
# DEBUG:numba.core.byteflow:stack ['$phi128.0', '$phi128.1', '$phi128.2', '$x130.4', '$y132.5']
# DEBUG:numba.core.byteflow:dispatch pc=136, inst=POP_JUMP_IF_FALSE(arg=73, lineno=20)
# DEBUG:numba.core.byteflow:stack ['$phi128.0', '$phi128.1', '$phi128.2', '$134compare_op.6']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=138, stack=('$phi128.0', '$phi128.1', '$phi128.2'), blockstack=(), npush=0), Edge(pc=144, stack=('$phi128.0', '$phi128.1', '$phi128.2'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=28 nstack_initial=1), State(pc_initial=278 nstack_initial=2), State(pc_initial=330 nstack_initial=2), State(pc_initial=88 nstack_initial=2), State(pc_initial=138 nstack_initial=3), State(pc_initial=144 nstack_initial=3)])
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=278 nstack_initial=2), State(pc_initial=330 nstack_initial=2), State(pc_initial=88 nstack_initial=2), State(pc_initial=138 nstack_initial=3), State(pc_initial=144 nstack_initial=3)])
# DEBUG:numba.core.byteflow:stack: ['$phi278.0', '$phi278.1']
# DEBUG:numba.core.byteflow:dispatch pc=278, inst=LOAD_FAST(arg=13, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi278.0', '$phi278.1']
# DEBUG:numba.core.byteflow:dispatch pc=280, inst=LOAD_FAST(arg=14, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi278.0', '$phi278.1', '$index278.2']
# DEBUG:numba.core.byteflow:dispatch pc=282, inst=COMPARE_OP(arg=2, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi278.0', '$phi278.1', '$index278.2', '$y280.3']
# DEBUG:numba.core.byteflow:dispatch pc=284, inst=POP_JUMP_IF_TRUE(arg=162, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi278.0', '$phi278.1', '$282compare_op.4']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=286, stack=('$phi278.0', '$phi278.1'), blockstack=(), npush=0), Edge(pc=322, stack=('$phi278.0', '$phi278.1'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=330 nstack_initial=2), State(pc_initial=88 nstack_initial=2), State(pc_initial=138 nstack_initial=3), State(pc_initial=144 nstack_initial=3), State(pc_initial=286 nstack_initial=2), State(pc_initial=322 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: ['$phi330.0', '$phi330.1']
# DEBUG:numba.core.byteflow:dispatch pc=330, inst=JUMP_ABSOLUTE(arg=128, lineno=36)
# DEBUG:numba.core.byteflow:stack ['$phi330.0', '$phi330.1']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=254, stack=('$phi330.0', '$phi330.1'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=88 nstack_initial=2), State(pc_initial=138 nstack_initial=3), State(pc_initial=144 nstack_initial=3), State(pc_initial=286 nstack_initial=2), State(pc_initial=322 nstack_initial=2), State(pc_initial=254 nstack_initial=2)])
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=138 nstack_initial=3), State(pc_initial=144 nstack_initial=3), State(pc_initial=286 nstack_initial=2), State(pc_initial=322 nstack_initial=2), State(pc_initial=254 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: ['$phi138.0', '$phi138.1', '$phi138.2']
# DEBUG:numba.core.byteflow:dispatch pc=138, inst=LOAD_FAST(arg=5, lineno=21)
# DEBUG:numba.core.byteflow:stack ['$phi138.0', '$phi138.1', '$phi138.2']
# DEBUG:numba.core.byteflow:dispatch pc=140, inst=STORE_FAST(arg=12, lineno=21)
# DEBUG:numba.core.byteflow:stack ['$phi138.0', '$phi138.1', '$phi138.2', '$max_neg_val138.3']
# DEBUG:numba.core.byteflow:dispatch pc=142, inst=JUMP_FORWARD(arg=8, lineno=21)
# DEBUG:numba.core.byteflow:stack ['$phi138.0', '$phi138.1', '$phi138.2']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=160, stack=('$phi138.0', '$phi138.1', '$phi138.2'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=144 nstack_initial=3), State(pc_initial=286 nstack_initial=2), State(pc_initial=322 nstack_initial=2), State(pc_initial=254 nstack_initial=2), State(pc_initial=160 nstack_initial=3)])
# DEBUG:numba.core.byteflow:stack: ['$phi144.0', '$phi144.1', '$phi144.2']
# DEBUG:numba.core.byteflow:dispatch pc=144, inst=LOAD_FAST(arg=8, lineno=23)
# DEBUG:numba.core.byteflow:stack ['$phi144.0', '$phi144.1', '$phi144.2']
# DEBUG:numba.core.byteflow:dispatch pc=146, inst=LOAD_FAST(arg=14, lineno=23)
# DEBUG:numba.core.byteflow:stack ['$phi144.0', '$phi144.1', '$phi144.2', '$value144.3']
# DEBUG:numba.core.byteflow:dispatch pc=148, inst=LOAD_CONST(arg=4, lineno=23)
# DEBUG:numba.core.byteflow:stack ['$phi144.0', '$phi144.1', '$phi144.2', '$value144.3', '$y146.4']
# DEBUG:numba.core.byteflow:dispatch pc=150, inst=BINARY_SUBTRACT(arg=None, lineno=23)
# DEBUG:numba.core.byteflow:stack ['$phi144.0', '$phi144.1', '$phi144.2', '$value144.3', '$y146.4', '$const148.5']
# DEBUG:numba.core.byteflow:dispatch pc=152, inst=LOAD_FAST(arg=15, lineno=23)
# DEBUG:numba.core.byteflow:stack ['$phi144.0', '$phi144.1', '$phi144.2', '$value144.3', '$150binary_subtract.6']
# DEBUG:numba.core.byteflow:dispatch pc=154, inst=BUILD_TUPLE(arg=2, lineno=23)
# DEBUG:numba.core.byteflow:stack ['$phi144.0', '$phi144.1', '$phi144.2', '$value144.3', '$150binary_subtract.6', '$x152.7']
# DEBUG:numba.core.byteflow:dispatch pc=156, inst=BINARY_SUBSCR(arg=None, lineno=23)
# DEBUG:numba.core.byteflow:stack ['$phi144.0', '$phi144.1', '$phi144.2', '$value144.3', '$154build_tuple.8']
# DEBUG:numba.core.byteflow:dispatch pc=158, inst=STORE_FAST(arg=12, lineno=23)
# DEBUG:numba.core.byteflow:stack ['$phi144.0', '$phi144.1', '$phi144.2', '$156binary_subscr.9']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=160, stack=('$phi144.0', '$phi144.1', '$phi144.2'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=286 nstack_initial=2), State(pc_initial=322 nstack_initial=2), State(pc_initial=254 nstack_initial=2), State(pc_initial=160 nstack_initial=3), State(pc_initial=160 nstack_initial=3)])
# DEBUG:numba.core.byteflow:stack: ['$phi286.0', '$phi286.1']
# DEBUG:numba.core.byteflow:dispatch pc=286, inst=LOAD_FAST(arg=8, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi286.0', '$phi286.1']
# DEBUG:numba.core.byteflow:dispatch pc=288, inst=LOAD_FAST(arg=14, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi286.0', '$phi286.1', '$value286.2']
# DEBUG:numba.core.byteflow:dispatch pc=290, inst=LOAD_CONST(arg=4, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi286.0', '$phi286.1', '$value286.2', '$y288.3']
# DEBUG:numba.core.byteflow:dispatch pc=292, inst=BINARY_SUBTRACT(arg=None, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi286.0', '$phi286.1', '$value286.2', '$y288.3', '$const290.4']
# DEBUG:numba.core.byteflow:dispatch pc=294, inst=LOAD_FAST(arg=13, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi286.0', '$phi286.1', '$value286.2', '$292binary_subtract.5']
# DEBUG:numba.core.byteflow:dispatch pc=296, inst=BUILD_TUPLE(arg=2, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi286.0', '$phi286.1', '$value286.2', '$292binary_subtract.5', '$index294.6']
# DEBUG:numba.core.byteflow:dispatch pc=298, inst=BINARY_SUBSCR(arg=None, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi286.0', '$phi286.1', '$value286.2', '$296build_tuple.7']
# DEBUG:numba.core.byteflow:dispatch pc=300, inst=LOAD_FAST(arg=8, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi286.0', '$phi286.1', '$298binary_subscr.8']
# DEBUG:numba.core.byteflow:dispatch pc=302, inst=LOAD_FAST(arg=14, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi286.0', '$phi286.1', '$298binary_subscr.8', '$value300.9']
# DEBUG:numba.core.byteflow:dispatch pc=304, inst=LOAD_CONST(arg=4, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi286.0', '$phi286.1', '$298binary_subscr.8', '$value300.9', '$y302.10']
# DEBUG:numba.core.byteflow:dispatch pc=306, inst=BINARY_SUBTRACT(arg=None, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi286.0', '$phi286.1', '$298binary_subscr.8', '$value300.9', '$y302.10', '$const304.11']
# DEBUG:numba.core.byteflow:dispatch pc=308, inst=LOAD_FAST(arg=13, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi286.0', '$phi286.1', '$298binary_subscr.8', '$value300.9', '$306binary_subtract.12']
# DEBUG:numba.core.byteflow:dispatch pc=310, inst=LOAD_CONST(arg=4, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi286.0', '$phi286.1', '$298binary_subscr.8', '$value300.9', '$306binary_subtract.12', '$index308.13']
# DEBUG:numba.core.byteflow:dispatch pc=312, inst=BINARY_SUBTRACT(arg=None, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi286.0', '$phi286.1', '$298binary_subscr.8', '$value300.9', '$306binary_subtract.12', '$index308.13', '$const310.14']
# DEBUG:numba.core.byteflow:dispatch pc=314, inst=BUILD_TUPLE(arg=2, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi286.0', '$phi286.1', '$298binary_subscr.8', '$value300.9', '$306binary_subtract.12', '$312binary_subtract.15']
# DEBUG:numba.core.byteflow:dispatch pc=316, inst=BINARY_SUBSCR(arg=None, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi286.0', '$phi286.1', '$298binary_subscr.8', '$value300.9', '$314build_tuple.16']
# DEBUG:numba.core.byteflow:dispatch pc=318, inst=COMPARE_OP(arg=0, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi286.0', '$phi286.1', '$298binary_subscr.8', '$316binary_subscr.17']
# DEBUG:numba.core.byteflow:dispatch pc=320, inst=POP_JUMP_IF_FALSE(arg=166, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$phi286.0', '$phi286.1', '$318compare_op.18']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=322, stack=('$phi286.0', '$phi286.1'), blockstack=(), npush=0), Edge(pc=330, stack=('$phi286.0', '$phi286.1'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=322 nstack_initial=2), State(pc_initial=254 nstack_initial=2), State(pc_initial=160 nstack_initial=3), State(pc_initial=160 nstack_initial=3), State(pc_initial=322 nstack_initial=2), State(pc_initial=330 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: ['$phi322.0', '$phi322.1']
# DEBUG:numba.core.byteflow:dispatch pc=322, inst=LOAD_FAST(arg=13, lineno=36)
# DEBUG:numba.core.byteflow:stack ['$phi322.0', '$phi322.1']
# DEBUG:numba.core.byteflow:dispatch pc=324, inst=LOAD_CONST(arg=4, lineno=36)
# DEBUG:numba.core.byteflow:stack ['$phi322.0', '$phi322.1', '$index322.2']
# DEBUG:numba.core.byteflow:dispatch pc=326, inst=BINARY_SUBTRACT(arg=None, lineno=36)
# DEBUG:numba.core.byteflow:stack ['$phi322.0', '$phi322.1', '$index322.2', '$const324.3']
# DEBUG:numba.core.byteflow:dispatch pc=328, inst=STORE_FAST(arg=13, lineno=36)
# DEBUG:numba.core.byteflow:stack ['$phi322.0', '$phi322.1', '$326binary_subtract.4']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=330, stack=('$phi322.0', '$phi322.1'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=254 nstack_initial=2), State(pc_initial=160 nstack_initial=3), State(pc_initial=160 nstack_initial=3), State(pc_initial=322 nstack_initial=2), State(pc_initial=330 nstack_initial=2), State(pc_initial=330 nstack_initial=2)])
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=160 nstack_initial=3), State(pc_initial=160 nstack_initial=3), State(pc_initial=322 nstack_initial=2), State(pc_initial=330 nstack_initial=2), State(pc_initial=330 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: ['$phi160.0', '$phi160.1', '$phi160.2']
# DEBUG:numba.core.byteflow:dispatch pc=160, inst=LOAD_FAST(arg=15, lineno=24)
# DEBUG:numba.core.byteflow:stack ['$phi160.0', '$phi160.1', '$phi160.2']
# DEBUG:numba.core.byteflow:dispatch pc=162, inst=LOAD_CONST(arg=1, lineno=24)
# DEBUG:numba.core.byteflow:stack ['$phi160.0', '$phi160.1', '$phi160.2', '$x160.3']
# DEBUG:numba.core.byteflow:dispatch pc=164, inst=COMPARE_OP(arg=2, lineno=24)
# DEBUG:numba.core.byteflow:stack ['$phi160.0', '$phi160.1', '$phi160.2', '$x160.3', '$const162.4']
# DEBUG:numba.core.byteflow:dispatch pc=166, inst=POP_JUMP_IF_FALSE(arg=95, lineno=24)
# DEBUG:numba.core.byteflow:stack ['$phi160.0', '$phi160.1', '$phi160.2', '$164compare_op.5']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=168, stack=('$phi160.0', '$phi160.1', '$phi160.2'), blockstack=(), npush=0), Edge(pc=188, stack=('$phi160.0', '$phi160.1', '$phi160.2'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=160 nstack_initial=3), State(pc_initial=322 nstack_initial=2), State(pc_initial=330 nstack_initial=2), State(pc_initial=330 nstack_initial=2), State(pc_initial=168 nstack_initial=3), State(pc_initial=188 nstack_initial=3)])
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=322 nstack_initial=2), State(pc_initial=330 nstack_initial=2), State(pc_initial=330 nstack_initial=2), State(pc_initial=168 nstack_initial=3), State(pc_initial=188 nstack_initial=3)])
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=330 nstack_initial=2), State(pc_initial=330 nstack_initial=2), State(pc_initial=168 nstack_initial=3), State(pc_initial=188 nstack_initial=3)])
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=330 nstack_initial=2), State(pc_initial=168 nstack_initial=3), State(pc_initial=188 nstack_initial=3)])
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=168 nstack_initial=3), State(pc_initial=188 nstack_initial=3)])
# DEBUG:numba.core.byteflow:stack: ['$phi168.0', '$phi168.1', '$phi168.2']
# DEBUG:numba.core.byteflow:dispatch pc=168, inst=LOAD_FAST(arg=14, lineno=25)
# DEBUG:numba.core.byteflow:stack ['$phi168.0', '$phi168.1', '$phi168.2']
# DEBUG:numba.core.byteflow:dispatch pc=170, inst=LOAD_CONST(arg=1, lineno=25)
# DEBUG:numba.core.byteflow:stack ['$phi168.0', '$phi168.1', '$phi168.2', '$y168.3']
# DEBUG:numba.core.byteflow:dispatch pc=172, inst=COMPARE_OP(arg=2, lineno=25)
# DEBUG:numba.core.byteflow:stack ['$phi168.0', '$phi168.1', '$phi168.2', '$y168.3', '$const170.4']
# DEBUG:numba.core.byteflow:dispatch pc=174, inst=POP_JUMP_IF_FALSE(arg=92, lineno=25)
# DEBUG:numba.core.byteflow:stack ['$phi168.0', '$phi168.1', '$phi168.2', '$172compare_op.5']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=176, stack=('$phi168.0', '$phi168.1', '$phi168.2'), blockstack=(), npush=0), Edge(pc=182, stack=('$phi168.0', '$phi168.1', '$phi168.2'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=188 nstack_initial=3), State(pc_initial=176 nstack_initial=3), State(pc_initial=182 nstack_initial=3)])
# DEBUG:numba.core.byteflow:stack: ['$phi188.0', '$phi188.1', '$phi188.2']
# DEBUG:numba.core.byteflow:dispatch pc=188, inst=LOAD_FAST(arg=8, lineno=30)
# DEBUG:numba.core.byteflow:stack ['$phi188.0', '$phi188.1', '$phi188.2']
# DEBUG:numba.core.byteflow:dispatch pc=190, inst=LOAD_FAST(arg=14, lineno=30)
# DEBUG:numba.core.byteflow:stack ['$phi188.0', '$phi188.1', '$phi188.2', '$value188.3']
# DEBUG:numba.core.byteflow:dispatch pc=192, inst=LOAD_CONST(arg=4, lineno=30)
# DEBUG:numba.core.byteflow:stack ['$phi188.0', '$phi188.1', '$phi188.2', '$value188.3', '$y190.4']
# DEBUG:numba.core.byteflow:dispatch pc=194, inst=BINARY_SUBTRACT(arg=None, lineno=30)
# DEBUG:numba.core.byteflow:stack ['$phi188.0', '$phi188.1', '$phi188.2', '$value188.3', '$y190.4', '$const192.5']
# DEBUG:numba.core.byteflow:dispatch pc=196, inst=LOAD_FAST(arg=15, lineno=30)
# DEBUG:numba.core.byteflow:stack ['$phi188.0', '$phi188.1', '$phi188.2', '$value188.3', '$194binary_subtract.6']
# DEBUG:numba.core.byteflow:dispatch pc=198, inst=LOAD_CONST(arg=4, lineno=30)
# DEBUG:numba.core.byteflow:stack ['$phi188.0', '$phi188.1', '$phi188.2', '$value188.3', '$194binary_subtract.6', '$x196.7']
# DEBUG:numba.core.byteflow:dispatch pc=200, inst=BINARY_SUBTRACT(arg=None, lineno=30)
# DEBUG:numba.core.byteflow:stack ['$phi188.0', '$phi188.1', '$phi188.2', '$value188.3', '$194binary_subtract.6', '$x196.7', '$const198.8']
# DEBUG:numba.core.byteflow:dispatch pc=202, inst=BUILD_TUPLE(arg=2, lineno=30)
# DEBUG:numba.core.byteflow:stack ['$phi188.0', '$phi188.1', '$phi188.2', '$value188.3', '$194binary_subtract.6', '$200binary_subtract.9']
# DEBUG:numba.core.byteflow:dispatch pc=204, inst=BINARY_SUBSCR(arg=None, lineno=30)
# DEBUG:numba.core.byteflow:stack ['$phi188.0', '$phi188.1', '$phi188.2', '$value188.3', '$202build_tuple.10']
# DEBUG:numba.core.byteflow:dispatch pc=206, inst=STORE_FAST(arg=11, lineno=30)
# DEBUG:numba.core.byteflow:stack ['$phi188.0', '$phi188.1', '$phi188.2', '$204binary_subscr.11']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=208, stack=('$phi188.0', '$phi188.1', '$phi188.2'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=176 nstack_initial=3), State(pc_initial=182 nstack_initial=3), State(pc_initial=208 nstack_initial=3)])
# DEBUG:numba.core.byteflow:stack: ['$phi176.0', '$phi176.1', '$phi176.2']
# DEBUG:numba.core.byteflow:dispatch pc=176, inst=LOAD_CONST(arg=3, lineno=26)
# DEBUG:numba.core.byteflow:stack ['$phi176.0', '$phi176.1', '$phi176.2']
# DEBUG:numba.core.byteflow:dispatch pc=178, inst=STORE_FAST(arg=11, lineno=26)
# DEBUG:numba.core.byteflow:stack ['$phi176.0', '$phi176.1', '$phi176.2', '$const176.3']
# DEBUG:numba.core.byteflow:dispatch pc=180, inst=JUMP_FORWARD(arg=13, lineno=26)
# DEBUG:numba.core.byteflow:stack ['$phi176.0', '$phi176.1', '$phi176.2']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=208, stack=('$phi176.0', '$phi176.1', '$phi176.2'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=182 nstack_initial=3), State(pc_initial=208 nstack_initial=3), State(pc_initial=208 nstack_initial=3)])
# DEBUG:numba.core.byteflow:stack: ['$phi182.0', '$phi182.1', '$phi182.2']
# DEBUG:numba.core.byteflow:dispatch pc=182, inst=LOAD_FAST(arg=5, lineno=28)
# DEBUG:numba.core.byteflow:stack ['$phi182.0', '$phi182.1', '$phi182.2']
# DEBUG:numba.core.byteflow:dispatch pc=184, inst=STORE_FAST(arg=11, lineno=28)
# DEBUG:numba.core.byteflow:stack ['$phi182.0', '$phi182.1', '$phi182.2', '$max_neg_val182.3']
# DEBUG:numba.core.byteflow:dispatch pc=186, inst=JUMP_FORWARD(arg=10, lineno=28)
# DEBUG:numba.core.byteflow:stack ['$phi182.0', '$phi182.1', '$phi182.2']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=208, stack=('$phi182.0', '$phi182.1', '$phi182.2'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=208 nstack_initial=3), State(pc_initial=208 nstack_initial=3), State(pc_initial=208 nstack_initial=3)])
# DEBUG:numba.core.byteflow:stack: ['$phi208.0', '$phi208.1', '$phi208.2']
# DEBUG:numba.core.byteflow:dispatch pc=208, inst=LOAD_FAST(arg=8, lineno=31)
# DEBUG:numba.core.byteflow:stack ['$phi208.0', '$phi208.1', '$phi208.2']
# DEBUG:numba.core.byteflow:dispatch pc=210, inst=LOAD_FAST(arg=14, lineno=31)
# DEBUG:numba.core.byteflow:stack ['$phi208.0', '$phi208.1', '$phi208.2', '$value208.3']
# DEBUG:numba.core.byteflow:dispatch pc=212, inst=LOAD_FAST(arg=15, lineno=31)
# DEBUG:numba.core.byteflow:stack ['$phi208.0', '$phi208.1', '$phi208.2', '$value208.3', '$y210.4']
# DEBUG:numba.core.byteflow:dispatch pc=214, inst=BUILD_TUPLE(arg=2, lineno=31)
# DEBUG:numba.core.byteflow:stack ['$phi208.0', '$phi208.1', '$phi208.2', '$value208.3', '$y210.4', '$x212.5']
# DEBUG:numba.core.byteflow:dispatch pc=216, inst=DUP_TOP_TWO(arg=None, lineno=31)
# DEBUG:numba.core.byteflow:stack ['$phi208.0', '$phi208.1', '$phi208.2', '$value208.3', '$214build_tuple.6']
# DEBUG:numba.core.byteflow:dispatch pc=218, inst=BINARY_SUBSCR(arg=None, lineno=31)
# DEBUG:numba.core.byteflow:stack ['$phi208.0', '$phi208.1', '$phi208.2', '$value208.3', '$214build_tuple.6', '$216dup_top_two.7', '$216dup_top_two.8']
# DEBUG:numba.core.byteflow:dispatch pc=220, inst=LOAD_GLOBAL(arg=3, lineno=31)
# DEBUG:numba.core.byteflow:stack ['$phi208.0', '$phi208.1', '$phi208.2', '$value208.3', '$214build_tuple.6', '$218binary_subscr.9']
# DEBUG:numba.core.byteflow:dispatch pc=222, inst=LOAD_FAST(arg=11, lineno=31)
# DEBUG:numba.core.byteflow:stack ['$phi208.0', '$phi208.1', '$phi208.2', '$value208.3', '$214build_tuple.6', '$218binary_subscr.9', '$220load_global.10']
# DEBUG:numba.core.byteflow:dispatch pc=224, inst=LOAD_FAST(arg=12, lineno=31)
# DEBUG:numba.core.byteflow:stack ['$phi208.0', '$phi208.1', '$phi208.2', '$value208.3', '$214build_tuple.6', '$218binary_subscr.9', '$220load_global.10', '$v_prev222.11']
# DEBUG:numba.core.byteflow:dispatch pc=226, inst=CALL_FUNCTION(arg=2, lineno=31)
# DEBUG:numba.core.byteflow:stack ['$phi208.0', '$phi208.1', '$phi208.2', '$value208.3', '$214build_tuple.6', '$218binary_subscr.9', '$220load_global.10', '$v_prev222.11', '$v_cur224.12']
# DEBUG:numba.core.byteflow:dispatch pc=228, inst=INPLACE_ADD(arg=None, lineno=31)
# DEBUG:numba.core.byteflow:stack ['$phi208.0', '$phi208.1', '$phi208.2', '$value208.3', '$214build_tuple.6', '$218binary_subscr.9', '$226call_function.13']
# DEBUG:numba.core.byteflow:dispatch pc=230, inst=ROT_THREE(arg=None, lineno=31)
# DEBUG:numba.core.byteflow:stack ['$phi208.0', '$phi208.1', '$phi208.2', '$value208.3', '$214build_tuple.6', '$228inplace_add.14']
# DEBUG:numba.core.byteflow:dispatch pc=232, inst=STORE_SUBSCR(arg=None, lineno=31)
# DEBUG:numba.core.byteflow:stack ['$phi208.0', '$phi208.1', '$phi208.2', '$228inplace_add.14', '$value208.3', '$214build_tuple.6']
# DEBUG:numba.core.byteflow:dispatch pc=234, inst=JUMP_ABSOLUTE(arg=64, lineno=31)
# DEBUG:numba.core.byteflow:stack ['$phi208.0', '$phi208.1', '$phi208.2']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=126, stack=('$phi208.0', '$phi208.1', '$phi208.2'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=208 nstack_initial=3), State(pc_initial=208 nstack_initial=3), State(pc_initial=126 nstack_initial=3)])
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=208 nstack_initial=3), State(pc_initial=126 nstack_initial=3)])
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=126 nstack_initial=3)])
# DEBUG:numba.core.byteflow:-------------------------Prune PHIs-------------------------
# DEBUG:numba.core.byteflow:Used_phis: defaultdict(<class 'set'>,
#             {State(pc_initial=0 nstack_initial=0): set(),
# ...
# DEBUG:numba.core.ssa:on stmt: $124get_iter.19 = getiter(value=$122call_function.18)
# DEBUG:numba.core.ssa:on stmt: $phi126.2 = $124get_iter.19
# DEBUG:numba.core.ssa:on stmt: jump 126
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 126
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x0000016BF7157A00>
# DEBUG:numba.core.ssa:on stmt: $126for_iter.3 = iternext(value=$phi126.2)
# DEBUG:numba.core.ssa:on stmt: $126for_iter.4 = pair_first(value=$126for_iter.3)
# DEBUG:numba.core.ssa:on stmt: $126for_iter.5 = pair_second(value=$126for_iter.3)
# DEBUG:numba.core.ssa:on stmt: $phi128.3 = $126for_iter.4
# DEBUG:numba.core.ssa:on stmt: branch $126for_iter.5, 128, 236
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 128
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x0000016BF7157A00>
# DEBUG:numba.core.ssa:on stmt: x = $phi128.3
# DEBUG:numba.core.ssa:on stmt: $134compare_op.6 = x == y
# DEBUG:numba.core.ssa:find_def var='y' stmt=$134compare_op.6 = x == y
# DEBUG:numba.core.ssa:find_def_from_top label 128
# DEBUG:numba.core.ssa:idom 126 from label 128
# DEBUG:numba.core.ssa:find_def_from_bottom label 126
# DEBUG:numba.core.ssa:find_def_from_top label 126
# DEBUG:numba.core.ssa:idom 90 from label 126
# DEBUG:numba.core.ssa:find_def_from_bottom label 90
# DEBUG:numba.core.ssa:on stmt: bool136 = global(bool: <class 'bool'>)
# DEBUG:numba.core.ssa:on stmt: $136pred = call bool136($134compare_op.6, func=bool136, args=(Var($134compare_op.6, core.py:20),), kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: branch $136pred, 138, 144
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 138
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x0000016BF7157A00>
# DEBUG:numba.core.ssa:on stmt: v_cur.1 = max_neg_val
# DEBUG:numba.core.ssa:on stmt: jump 160
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 144
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x0000016BF7157A00>
# DEBUG:numba.core.ssa:on stmt: $const148.5 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $150binary_subtract.6 = y - $const148.5
# DEBUG:numba.core.ssa:find_def var='y' stmt=$150binary_subtract.6 = y - $const148.5
# DEBUG:numba.core.ssa:find_def_from_top label 144
# DEBUG:numba.core.ssa:idom 128 from label 144
# DEBUG:numba.core.ssa:find_def_from_bottom label 128
# DEBUG:numba.core.ssa:find_def_from_top label 128
# DEBUG:numba.core.ssa:idom 126 from label 128
# DEBUG:numba.core.ssa:find_def_from_bottom label 126
# DEBUG:numba.core.ssa:find_def_from_top label 126
# DEBUG:numba.core.ssa:idom 90 from label 126
# DEBUG:numba.core.ssa:find_def_from_bottom label 90
# DEBUG:numba.core.ssa:on stmt: $154build_tuple.8 = build_tuple(items=[Var($150binary_subtract.6, core.py:23), Var(x, core.py:19)])
# DEBUG:numba.core.ssa:on stmt: v_cur.2 = getitem(value=value, index=$154build_tuple.8, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: jump 160
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 160
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x0000016BF7157A00>
# DEBUG:numba.core.ssa:on stmt: v_cur.3 = phi(incoming_values=[Var(v_cur.2, core.py:23), Var(v_cur.1, core.py:21)], incoming_blocks=[144, 138])
# DEBUG:numba.core.ssa:on stmt: $const162.4 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $164compare_op.5 = x == $const162.4
# DEBUG:numba.core.ssa:on stmt: bool166 = global(bool: <class 'bool'>)
# DEBUG:numba.core.ssa:on stmt: $166pred = call bool166($164compare_op.5, func=bool166, args=(Var($164compare_op.5, core.py:24),), kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: branch $166pred, 168, 188
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 168
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x0000016BF7157A00>
# DEBUG:numba.core.ssa:on stmt: $const170.4 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $172compare_op.5 = y == $const170.4
# DEBUG:numba.core.ssa:find_def var='y' stmt=$172compare_op.5 = y == $const170.4
# DEBUG:numba.core.ssa:find_def_from_top label 168
# DEBUG:numba.core.ssa:idom 160 from label 168
# DEBUG:numba.core.ssa:find_def_from_bottom label 160
# DEBUG:numba.core.ssa:find_def_from_top label 160
# DEBUG:numba.core.ssa:idom 128 from label 160
# DEBUG:numba.core.ssa:find_def_from_bottom label 128
# DEBUG:numba.core.ssa:find_def_from_top label 128
# DEBUG:numba.core.ssa:idom 126 from label 128
# DEBUG:numba.core.ssa:find_def_from_bottom label 126
# DEBUG:numba.core.ssa:find_def_from_top label 126
# DEBUG:numba.core.ssa:idom 90 from label 126
# DEBUG:numba.core.ssa:find_def_from_bottom label 90
# DEBUG:numba.core.ssa:on stmt: bool174 = global(bool: <class 'bool'>)
# DEBUG:numba.core.ssa:on stmt: $174pred = call bool174($172compare_op.5, func=bool174, args=(Var($172compare_op.5, core.py:25),), kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: branch $174pred, 176, 182
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 176
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x0000016BF7157A00>
# DEBUG:numba.core.ssa:on stmt: v_prev.1 = const(float, 0.0)
# DEBUG:numba.core.ssa:on stmt: jump 208
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 182
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x0000016BF7157A00>
# DEBUG:numba.core.ssa:on stmt: v_prev.2 = max_neg_val
# DEBUG:numba.core.ssa:on stmt: jump 208
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 188
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x0000016BF7157A00>
# DEBUG:numba.core.ssa:on stmt: $const192.5 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $194binary_subtract.6 = y - $const192.5
# DEBUG:numba.core.ssa:find_def var='y' stmt=$194binary_subtract.6 = y - $const192.5
# DEBUG:numba.core.ssa:find_def_from_top label 188
# DEBUG:numba.core.ssa:idom 160 from label 188
# DEBUG:numba.core.ssa:find_def_from_bottom label 160
# DEBUG:numba.core.ssa:find_def_from_top label 160
# DEBUG:numba.core.ssa:idom 128 from label 160
# DEBUG:numba.core.ssa:find_def_from_bottom label 128
# DEBUG:numba.core.ssa:find_def_from_top label 128
# DEBUG:numba.core.ssa:idom 126 from label 128
# DEBUG:numba.core.ssa:find_def_from_bottom label 126
# DEBUG:numba.core.ssa:find_def_from_top label 126
# DEBUG:numba.core.ssa:idom 90 from label 126
# DEBUG:numba.core.ssa:find_def_from_bottom label 90
# DEBUG:numba.core.ssa:on stmt: $const198.8 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $200binary_subtract.9 = x - $const198.8
# DEBUG:numba.core.ssa:on stmt: $202build_tuple.10 = build_tuple(items=[Var($194binary_subtract.6, core.py:30), Var($200binary_subtract.9, core.py:30)])
# DEBUG:numba.core.ssa:on stmt: v_prev.3 = getitem(value=value, index=$202build_tuple.10, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: jump 208
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 208
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x0000016BF7157A00>
# DEBUG:numba.core.ssa:on stmt: v_prev.4 = phi(incoming_values=[Var(v_prev.1, core.py:26), Var(v_prev.3, core.py:30), Var(v_prev.2, core.py:28)], incoming_blocks=[176, 188, 182])
# DEBUG:numba.core.ssa:on stmt: $214build_tuple.6 = build_tuple(items=[Var(y, core.py:18), Var(x, core.py:19)])
# DEBUG:numba.core.ssa:find_def var='y' stmt=$214build_tuple.6 = build_tuple(items=[Var(y, core.py:18), Var(x, core.py:19)])
# DEBUG:numba.core.ssa:find_def_from_top label 208
# DEBUG:numba.core.ssa:idom 160 from label 208
# DEBUG:numba.core.ssa:find_def_from_bottom label 160
# DEBUG:numba.core.ssa:find_def_from_top label 160
# DEBUG:numba.core.ssa:idom 128 from label 160
# DEBUG:numba.core.ssa:find_def_from_bottom label 128
# DEBUG:numba.core.ssa:find_def_from_top label 128
# DEBUG:numba.core.ssa:idom 126 from label 128
# DEBUG:numba.core.ssa:find_def_from_bottom label 126
# DEBUG:numba.core.ssa:find_def_from_top label 126
# DEBUG:numba.core.ssa:idom 90 from label 126
# DEBUG:numba.core.ssa:find_def_from_bottom label 90
# DEBUG:numba.core.ssa:on stmt: $218binary_subscr.9 = getitem(value=value, index=$214build_tuple.6, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $220load_global.10 = global(max: <built-in function max>)
# DEBUG:numba.core.ssa:on stmt: $226call_function.13 = call $220load_global.10(v_prev.4, v_cur.3, func=$220load_global.10, args=[Var(v_prev.4, core.py:31), Var(v_cur.3, core.py:31)], kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: $228inplace_add.14 = inplace_binop(fn=<built-in function iadd>, immutable_fn=<built-in function add>, lhs=$218binary_subscr.9, rhs=$226call_function.13, static_lhs=Undefined, static_rhs=Undefined)
# DEBUG:numba.core.ssa:on stmt: value[$214build_tuple.6] = $228inplace_add.14
# DEBUG:numba.core.ssa:on stmt: jump 126
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 236
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x0000016BF7157A00>
# DEBUG:numba.core.ssa:on stmt: jump 88
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 238
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x0000016BF7157A00>
# DEBUG:numba.core.ssa:on stmt: $238load_global.1 = global(range: <class 'range'>)
# DEBUG:numba.core.ssa:on stmt: $const242.3 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $244binary_subtract.4 = t_y - $const242.3
# DEBUG:numba.core.ssa:on stmt: $const246.5 = const(int, -1)
# DEBUG:numba.core.ssa:on stmt: $const248.6 = const(int, -1)
# DEBUG:numba.core.ssa:on stmt: $250call_function.7 = call $238load_global.1($244binary_subtract.4, $const246.5, $const248.6, func=$238load_global.1, args=[Var($244binary_subtract.4, core.py:33), Var($const246.5, core.py:33), Var($const248.6, core.py:33)], kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: $252get_iter.8 = getiter(value=$250call_function.7)
# DEBUG:numba.core.ssa:on stmt: $phi254.1 = $252get_iter.8
# DEBUG:numba.core.ssa:on stmt: jump 254
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 254
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x0000016BF7157A00>
# DEBUG:numba.core.ssa:on stmt: index.2 = phi(incoming_values=[Var(index.3, core.py:33), Var(index, core.py:16)], incoming_blocks=[330, 238])
# DEBUG:numba.core.ssa:on stmt: $254for_iter.2 = iternext(value=$phi254.1)
# DEBUG:numba.core.ssa:on stmt: $254for_iter.3 = pair_first(value=$254for_iter.2)
# DEBUG:numba.core.ssa:on stmt: $254for_iter.4 = pair_second(value=$254for_iter.2)
# DEBUG:numba.core.ssa:on stmt: $phi256.2 = $254for_iter.3
# DEBUG:numba.core.ssa:on stmt: branch $254for_iter.4, 256, 332
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 256
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x0000016BF7157A00>
# DEBUG:numba.core.ssa:on stmt: y.1 = $phi256.2
# DEBUG:numba.core.ssa:on stmt: $const258.3 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $266build_tuple.7 = build_tuple(items=[Var(y, core.py:18), Var(index.2, core.py:33)])
# DEBUG:numba.core.ssa:find_def var='y' stmt=$266build_tuple.7 = build_tuple(items=[Var(y, core.py:18), Var(index.2, core.py:33)])
# DEBUG:numba.core.ssa:replaced with: $266build_tuple.7 = build_tuple(items=[Var(y.1, core.py:33), Var(index.2, core.py:33)])
# DEBUG:numba.core.ssa:on stmt: path[$266build_tuple.7] = $const258.3
# DEBUG:numba.core.ssa:on stmt: $const272.9 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $274compare_op.10 = index.2 != $const272.9
# DEBUG:numba.core.ssa:on stmt: bool276 = global(bool: <class 'bool'>)
# DEBUG:numba.core.ssa:on stmt: $276pred = call bool276($274compare_op.10, func=bool276, args=(Var($274compare_op.10, core.py:35),), kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: branch $276pred, 278, 330
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 278
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x0000016BF7157A00>
# DEBUG:numba.core.ssa:on stmt: $282compare_op.4 = index.2 == y
# DEBUG:numba.core.ssa:find_def var='y' stmt=$282compare_op.4 = index.2 == y
# DEBUG:numba.core.ssa:find_def_from_top label 278
# DEBUG:numba.core.ssa:idom 256 from label 278
# DEBUG:numba.core.ssa:find_def_from_bottom label 256
# DEBUG:numba.core.ssa:replaced with: $282compare_op.4 = index.2 == y.1
# DEBUG:numba.core.ssa:on stmt: bool284 = global(bool: <class 'bool'>)
# DEBUG:numba.core.ssa:on stmt: $284pred = call bool284($282compare_op.4, func=bool284, args=(Var($282compare_op.4, core.py:35),), kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: branch $284pred, 322, 286
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 286
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x0000016BF7157A00>
# DEBUG:numba.core.ssa:on stmt: $const290.4 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $292binary_subtract.5 = y - $const290.4
# DEBUG:numba.core.ssa:find_def var='y' stmt=$292binary_subtract.5 = y - $const290.4
# DEBUG:numba.core.ssa:find_def_from_top label 286
# DEBUG:numba.core.ssa:idom 278 from label 286
# DEBUG:numba.core.ssa:find_def_from_bottom label 278
# DEBUG:numba.core.ssa:find_def_from_top label 278
# DEBUG:numba.core.ssa:idom 256 from label 278
# DEBUG:numba.core.ssa:find_def_from_bottom label 256
# DEBUG:numba.core.ssa:replaced with: $292binary_subtract.5 = y.1 - $const290.4
# DEBUG:numba.core.ssa:on stmt: $296build_tuple.7 = build_tuple(items=[Var($292binary_subtract.5, core.py:35), Var(index.2, core.py:33)])
# DEBUG:numba.core.ssa:on stmt: $298binary_subscr.8 = getitem(value=value, index=$296build_tuple.7, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $const304.11 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $306binary_subtract.12 = y - $const304.11
# DEBUG:numba.core.ssa:find_def var='y' stmt=$306binary_subtract.12 = y - $const304.11
# DEBUG:numba.core.ssa:find_def_from_top label 286
# DEBUG:numba.core.ssa:idom 278 from label 286
# DEBUG:numba.core.ssa:find_def_from_bottom label 278
# DEBUG:numba.core.ssa:find_def_from_top label 278
# DEBUG:numba.core.ssa:idom 256 from label 278
# DEBUG:numba.core.ssa:find_def_from_bottom label 256
# DEBUG:numba.core.ssa:replaced with: $306binary_subtract.12 = y.1 - $const304.11
# DEBUG:numba.core.ssa:on stmt: $const310.14 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $312binary_subtract.15 = index.2 - $const310.14
# DEBUG:numba.core.ssa:on stmt: $314build_tuple.16 = build_tuple(items=[Var($306binary_subtract.12, core.py:35), Var($312binary_subtract.15, core.py:35)])
# DEBUG:numba.core.ssa:on stmt: $316binary_subscr.17 = getitem(value=value, index=$314build_tuple.16, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $318compare_op.18 = $298binary_subscr.8 < $316binary_subscr.17
# DEBUG:numba.core.ssa:on stmt: bool320 = global(bool: <class 'bool'>)
# DEBUG:numba.core.ssa:on stmt: $320pred = call bool320($318compare_op.18, func=bool320, args=(Var($318compare_op.18, core.py:35),), kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: branch $320pred, 322, 330
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 322
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x0000016BF7157A00>
# DEBUG:numba.core.ssa:on stmt: $const324.3 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $326binary_subtract.4 = index.2 - $const324.3
# DEBUG:numba.core.ssa:on stmt: index.1 = $326binary_subtract.4
# DEBUG:numba.core.ssa:on stmt: jump 330
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 330
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x0000016BF7157A00>
# DEBUG:numba.core.ssa:on stmt: index.3 = phi(incoming_values=[Var(index.2, core.py:33), Var(index.1, core.py:36), Var(index.2, core.py:33)], incoming_blocks=[256, 322, 286])
# DEBUG:numba.core.ssa:on stmt: jump 254
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 332
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x0000016BF7157A00>
# DEBUG:numba.core.ssa:on stmt: jump 28
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 334
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x0000016BF7157A00>
# DEBUG:numba.core.ssa:on stmt: $const334.0 = const(NoneType, None)
# DEBUG:numba.core.ssa:on stmt: $336return_value.1 = cast(value=$const334.0)
# DEBUG:numba.core.ssa:on stmt: return $336return_value.1

# %%
logging.getLogger('numba').setLevel(logging.WARNING)
limitation = os.getenv("SYSTEM") == "spaces"  # limit text and audio length in huggingface spaces

hps_ms = utils.get_hparams_from_file(r'config/config.json')

audio_postprocess_ori = gr.Audio.postprocess

def audio_postprocess(self, y):
    data = audio_postprocess_ori(self, y)
    if data is None:
        return None
    return gr_processing_utils.encode_url_or_file_to_base64(data["name"])


gr.Audio.postprocess = audio_postprocess

def get_text(text, hps, is_symbol):
    text_norm, clean_text = text_to_sequence(text, hps.symbols, [] if is_symbol else hps.data.text_cleaners)
    if hps.data.add_blank:
        text_norm = commons.intersperse(text_norm, 0)
    text_norm = LongTensor(text_norm)
    return text_norm, clean_text

def create_tts_fn(net_g_ms, speaker_id):
    def tts_fn(text, language, noise_scale, noise_scale_w, length_scale, is_symbol):
        text = text.replace('\n', ' ').replace('\r', '').replace(" ", "")
        if limitation:
            text_len = len(re.sub("\[([A-Z]{2})\]", "", text))
            max_len = 100
            if is_symbol:
                max_len *= 3
            if text_len > max_len:
                return "Error: Text is too long", None
        if not is_symbol:
            if language == 0:
                text = f"[ZH]{text}[ZH]"
            elif language == 1:
                text = f"[JA]{text}[JA]"
            else:
                text = f"{text}"
        stn_tst, clean_text = get_text(text, hps_ms, is_symbol)
        with no_grad():
            x_tst = stn_tst.unsqueeze(0).to(device)
            x_tst_lengths = LongTensor([stn_tst.size(0)]).to(device)
            sid = LongTensor([speaker_id]).to(device)
            audio = net_g_ms.infer(x_tst, x_tst_lengths, sid=sid, noise_scale=noise_scale, noise_scale_w=noise_scale_w,
                                   length_scale=length_scale)[0][0, 0].data.cpu().float().numpy()

        return "Success", (22050, audio)
    return tts_fn

def create_to_symbol_fn(hps):
    def to_symbol_fn(is_symbol_input, input_text, temp_lang):
        if temp_lang == 0:
            clean_text = f'[ZH]{input_text}[ZH]'
        elif temp_lang == 1:
            clean_text = f'[JA]{input_text}[JA]'
        else:
            clean_text = input_text
        return _clean_text(clean_text, hps.data.text_cleaners) if is_symbol_input else ''

    return to_symbol_fn
def change_lang(language):
    if language == 0:
        return 0.6, 0.668, 1.2
    elif language == 1:
        return 0.6, 0.668, 1
    else:
        return 0.6, 0.668, 1

download_audio_js = """
() =>{{
    let root = document.querySelector("body > gradio-app");
    if (root.shadowRoot != null)
        root = root.shadowRoot;
    let audio = root.querySelector("#tts-audio-{audio_id}").querySelector("audio");
    let text = root.querySelector("#input-text-{audio_id}").querySelector("textarea");
    if (audio == undefined)
        return;
    text = text.value;
    if (text == undefined)
        text = Math.floor(Math.random()*100000000);
    audio = audio.src;
    let oA = document.createElement("a");
    oA.download = text.substr(0, 20)+'.wav';
    oA.href = audio;
    document.body.appendChild(oA);
    oA.click();
    oA.remove();
}}
"""
if __name__ == '__main__':
    args = argparse.Namespace()
    args.device = 'cpu'
    args.api = False
    args.share = False
    args.all = False
    # 设置其他需要的属性

    device = torch.device(args.device)
    categories = ["Honkai: Star Rail", "Blue Archive", "Lycoris Recoil"]
    others = {
        "Princess Connect! Re:Dive": "https://huggingface.co/spaces/sayashi/vits-models-pcr",
        "Genshin Impact": "https://huggingface.co/spaces/sayashi/vits-models-genshin-bh3",
        "Honkai Impact 3rd": "https://huggingface.co/spaces/sayashi/vits-models-genshin-bh3",
        "Overwatch 2": "https://huggingface.co/spaces/sayashi/vits-models-ow2",
    }
    if args.all:
        categories = ["Honkai: Star Rail", "Blue Archive", "Lycoris Recoil", "Princess Connect! Re:Dive", "Genshin Impact", "Honkai Impact 3rd", "Overwatch 2"]
        others = {}
    models = []
# 其余代码...

    with open("pretrained_models/info.json", "r", encoding="utf-8") as f:
        models_info = json.load(f)
    for i, info in models_info.items():
        if info['title'].split("-")[0] not in categories or not info['enable']:
            continue
        sid = info['sid']
        name_en = info['name_en']
        name_zh = info['name_zh']
        title = info['title']
        cover = f"pretrained_models/{i}/{info['cover']}"
        example = info['example']
        language = info['language']
        net_g_ms = SynthesizerTrn(
            len(hps_ms.symbols),
            hps_ms.data.filter_length // 2 + 1,
            hps_ms.train.segment_size // hps_ms.data.hop_length,
            n_speakers=hps_ms.data.n_speakers if info['type'] == "multi" else 0,
            **hps_ms.model)
        utils.load_checkpoint(f'pretrained_models/{i}/{i}.pth', net_g_ms, None)
        _ = net_g_ms.eval().to(device)
        models.append((sid, name_en, name_zh, title, cover, example, language, net_g_ms, create_tts_fn(net_g_ms, sid), create_to_symbol_fn(hps_ms)))
    with gr.Blocks() as app:
        gr.Markdown(
            "# <center> vits-models\n"
            "## <center> Please do not generate content that could infringe upon the rights or cause harm to individuals or organizations.\n"
            "## <center> 请不要生成会对个人以及组织造成侵害的内容\n\n"
            "[![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/10QOk9NPgoKZUXkIhhuVaZ7SYra1MPMKH?usp=share_link)\n\n"
            "[![Duplicate this Space](https://huggingface.co/datasets/huggingface/badges/raw/main/duplicate-this-space-sm-dark.svg)](https://huggingface.co/spaces/sayashi/vits-models?duplicate=true)\n\n"
            "[![Finetune your own model](https://badgen.net/badge/icon/github?icon=github&label=Finetune%20your%20own%20model)](https://github.com/SayaSS/vits-finetuning)"
        )

        with gr.Tabs():
            for category in categories:
                with gr.TabItem(category):
                    with gr.TabItem("EN"):
                        for (sid, name_en, name_zh, title, cover, example, language, net_g_ms, tts_fn, to_symbol_fn) in models:
                            if title.split("-")[0] != category:
                                continue
                            with gr.TabItem(name_en):
                                with gr.Row():
                                    gr.Markdown(
                                        '<div align="center">'
                                        f'<a><strong>{title}</strong></a>'
                                        f'<img style="width:auto;height:300px;" src="file/{cover}">' if cover else ""
                                        '</div>'
                                    )
                                with gr.Row():
                                    with gr.Column():
                                        input_text = gr.Textbox(label="Text (100 words limitation)" if limitation else "Text", lines=5, value=example, elem_id=f"input-text-en-{name_en.replace(' ','')}")
                                        lang = gr.Dropdown(label="Language", choices=["Chinese", "Japanese", "Mix（wrap the Chinese text with [ZH][ZH], wrap the Japanese text with [JA][JA]）"],
                                                    type="index", value=language)
                                        with gr.Accordion(label="Advanced Options", open=False):
                                            symbol_input = gr.Checkbox(value=False, label="Symbol input")
                                            symbol_list = gr.Dataset(label="Symbol list", components=[input_text],
                                                                     samples=[[x] for x in hps_ms.symbols])
                                            symbol_list_json = gr.Json(value=hps_ms.symbols, visible=False)
                                        btn = gr.Button(value="Generate", variant="primary")
                                        with gr.Row():
                                            ns = gr.Slider(label="noise_scale", minimum=0.1, maximum=1.0, step=0.1, value=0.6, interactive=True)
                                            nsw = gr.Slider(label="noise_scale_w", minimum=0.1, maximum=1.0, step=0.1, value=0.668, interactive=True)
                                            ls = gr.Slider(label="length_scale", minimum=0.1, maximum=2.0, step=0.1, value=1.2 if language=="Chinese" else 1, interactive=True)
                                    with gr.Column():
                                        o1 = gr.Textbox(label="Output Message")
                                        o2 = gr.Audio(label="Output Audio", elem_id=f"tts-audio-en-{name_en.replace(' ','')}")
                                        download = gr.Button("Download Audio")
                                    btn.click(tts_fn, inputs=[input_text, lang,  ns, nsw, ls, symbol_input], outputs=[o1, o2], api_name=f"tts-{name_en}")
                                    download.click(None, [], [], _js=download_audio_js.format(audio_id=f"en-{name_en.replace(' ', '')}"))
                                    lang.change(change_lang, inputs=[lang], outputs=[ns, nsw, ls])
                                    symbol_input.change(
                                        to_symbol_fn,
                                        [symbol_input, input_text, lang],
                                        [input_text]
                                    )
                                    symbol_list.click(None, [symbol_list, symbol_list_json], [input_text],
                                                      _js=f"""
                                    (i,symbols) => {{
                                        let root = document.querySelector("body > gradio-app");
                                        if (root.shadowRoot != null)
                                            root = root.shadowRoot;
                                        let text_input = root.querySelector("#input-text-en-{name_en.replace(' ', '')}").querySelector("textarea");
                                        let startPos = text_input.selectionStart;
                                        let endPos = text_input.selectionEnd;
                                        let oldTxt = text_input.value;
                                        let result = oldTxt.substring(0, startPos) + symbols[i] + oldTxt.substring(endPos);
                                        text_input.value = result;
                                        let x = window.scrollX, y = window.scrollY;
                                        text_input.focus();
                                        text_input.selectionStart = startPos + symbols[i].length;
                                        text_input.selectionEnd = startPos + symbols[i].length;
                                        text_input.blur();
                                        window.scrollTo(x, y);
                                        return text_input.value;
                                    }}""")
                    with gr.TabItem("中文"):
                        for (sid, name_en, name_zh, title, cover, example, language,  net_g_ms, tts_fn, to_symbol_fn) in models:
                            if title.split("-")[0] != category:
                                continue
                            with gr.TabItem(name_zh):
                                with gr.Row():
                                    gr.Markdown(
                                        '<div align="center">'
                                        f'<a><strong>{title}</strong></a>'
                                        f'<img style="width:auto;height:300px;" src="file/{cover}">' if cover else ""
                                        '</div>'
                                    )
                                with gr.Row():
                                    with gr.Column():
                                        input_text = gr.Textbox(label="文本 (100字上限)" if limitation else "文本", lines=5, value=example, elem_id=f"input-text-zh-{name_zh}")
                                        lang = gr.Dropdown(label="语言", choices=["中文", "日语", "中日混合（中文用[ZH][ZH]包裹起来，日文用[JA][JA]包裹起来）"],
                                                    type="index", value="中文"if language == "Chinese" else "日语")
                                        with gr.Accordion(label="高级选项", open=False):
                                            symbol_input = gr.Checkbox(value=False, label="符号输入")
                                            symbol_list = gr.Dataset(label="符号列表", components=[input_text],
                                                                     samples=[[x] for x in hps_ms.symbols])
                                            symbol_list_json = gr.Json(value=hps_ms.symbols, visible=False)
                                        btn = gr.Button(value="生成", variant="primary")
                                        with gr.Row():
                                            ns = gr.Slider(label="控制感情变化程度", minimum=0.1, maximum=1.0, step=0.1, value=0.6, interactive=True)
                                            nsw = gr.Slider(label="控制音素发音长度", minimum=0.1, maximum=1.0, step=0.1, value=0.668, interactive=True)
                                            ls = gr.Slider(label="控制整体语速", minimum=0.1, maximum=2.0, step=0.1, value=1.2 if language=="Chinese" else 1, interactive=True)
                                    with gr.Column():
                                        o1 = gr.Textbox(label="输出信息")
                                        o2 = gr.Audio(label="输出音频", elem_id=f"tts-audio-zh-{name_zh}")
                                        download = gr.Button("下载音频")
                                    btn.click(tts_fn, inputs=[input_text, lang,  ns, nsw, ls, symbol_input], outputs=[o1, o2])
                                    download.click(None, [], [], _js=download_audio_js.format(audio_id=f"zh-{name_zh}"))
                                    lang.change(change_lang, inputs=[lang], outputs=[ns, nsw, ls])
                                    symbol_input.change(
                                        to_symbol_fn,
                                        [symbol_input, input_text, lang],
                                        [input_text]
                                    )
                                    symbol_list.click(None, [symbol_list, symbol_list_json], [input_text],
                                                      _js=f"""
                                    (i,symbols) => {{
                                        let root = document.querySelector("body > gradio-app");
                                        if (root.shadowRoot != null)
                                            root = root.shadowRoot;
                                        let text_input = root.querySelector("#input-text-zh-{name_zh}").querySelector("textarea");
                                        let startPos = text_input.selectionStart;
                                        let endPos = text_input.selectionEnd;
                                        let oldTxt = text_input.value;
                                        let result = oldTxt.substring(0, startPos) + symbols[i] + oldTxt.substring(endPos);
                                        text_input.value = result;
                                        let x = window.scrollX, y = window.scrollY;
                                        text_input.focus();
                                        text_input.selectionStart = startPos + symbols[i].length;
                                        text_input.selectionEnd = startPos + symbols[i].length;
                                        text_input.blur();
                                        window.scrollTo(x, y);
                                        return text_input.value;
                                    }}""")
            for category, link in others.items():
                with gr.TabItem(category):
                    gr.Markdown(
                        f'''
                        <center>
                          <h2>Click to Go</h2>
                          <a href="{link}">
                            <img src="https://huggingface.co/datasets/huggingface/badges/raw/main/open-in-hf-spaces-xl-dark.svg"
                          </a>
                        </center>
                        '''
                    )
    app.queue(concurrency_count=1, api_open=args.api).launch(share=args.share)
# Out:
# INFO:root:Loaded checkpoint 'pretrained_models/kafka/kafka.pth' (iteration 126)
# INFO:root:Loaded checkpoint 'pretrained_models/herta/herta.pth' (iteration 126)
# INFO:root:Loaded checkpoint 'pretrained_models/momoi/momoi.pth' (iteration 489)
# INFO:root:dec.cond.weight is not in the checkpoint
# INFO:root:dec.cond.bias is not in the checkpoint
# INFO:root:enc_q.enc.cond_layer.bias is not in the checkpoint
# INFO:root:enc_q.enc.cond_layer.weight_g is not in the checkpoint
# INFO:root:enc_q.enc.cond_layer.weight_v is not in the checkpoint
# INFO:root:flow.flows.0.enc.cond_layer.bias is not in the checkpoint
# INFO:root:flow.flows.0.enc.cond_layer.weight_g is not in the checkpoint
# INFO:root:flow.flows.0.enc.cond_layer.weight_v is not in the checkpoint
# INFO:root:flow.flows.2.enc.cond_layer.bias is not in the checkpoint
# INFO:root:flow.flows.2.enc.cond_layer.weight_g is not in the checkpoint
# INFO:root:flow.flows.2.enc.cond_layer.weight_v is not in the checkpoint
# INFO:root:flow.flows.4.enc.cond_layer.bias is not in the checkpoint
# INFO:root:flow.flows.4.enc.cond_layer.weight_g is not in the checkpoint
# INFO:root:flow.flows.4.enc.cond_layer.weight_v is not in the checkpoint
# INFO:root:flow.flows.6.enc.cond_layer.bias is not in the checkpoint
# INFO:root:flow.flows.6.enc.cond_layer.weight_g is not in the checkpoint
# INFO:root:flow.flows.6.enc.cond_layer.weight_v is not in the checkpoint
# INFO:root:dp.cond.weight is not in the checkpoint
# INFO:root:dp.cond.bias is not in the checkpoint
# INFO:root:Loaded checkpoint 'pretrained_models/chisato/chisato.pth' (iteration 251)
# INFO:root:dec.cond.weight is not in the checkpoint
# INFO:root:dec.cond.bias is not in the checkpoint
# INFO:root:enc_q.enc.cond_layer.bias is not in the checkpoint
# INFO:root:enc_q.enc.cond_layer.weight_g is not in the checkpoint
# INFO:root:enc_q.enc.cond_layer.weight_v is not in the checkpoint
# INFO:root:flow.flows.0.enc.cond_layer.bias is not in the checkpoint
# INFO:root:flow.flows.0.enc.cond_layer.weight_g is not in the checkpoint
# INFO:root:flow.flows.0.enc.cond_layer.weight_v is not in the checkpoint
# INFO:root:flow.flows.2.enc.cond_layer.bias is not in the checkpoint
# INFO:root:flow.flows.2.enc.cond_layer.weight_g is not in the checkpoint
# INFO:root:flow.flows.2.enc.cond_layer.weight_v is not in the checkpoint
# INFO:root:flow.flows.4.enc.cond_layer.bias is not in the checkpoint
# INFO:root:flow.flows.4.enc.cond_layer.weight_g is not in the checkpoint
# INFO:root:flow.flows.4.enc.cond_layer.weight_v is not in the checkpoint
# INFO:root:flow.flows.6.enc.cond_layer.bias is not in the checkpoint
# INFO:root:flow.flows.6.enc.cond_layer.weight_g is not in the checkpoint
# INFO:root:flow.flows.6.enc.cond_layer.weight_v is not in the checkpoint
# INFO:root:dp.cond.weight is not in the checkpoint
# INFO:root:dp.cond.bias is not in the checkpoint
# INFO:root:Loaded checkpoint 'pretrained_models/takina/takina.pth' (iteration 201)
# INFO:root:Loaded checkpoint 'pretrained_models/iroha/iroha.pth' (iteration 1126)
# INFO:root:Loaded checkpoint 'pretrained_models/mika/mika.pth' (iteration 858)
# INFO:root:Loaded checkpoint 'pretrained_models/miyu/miyu.pth' (iteration 1376)
# INFO:root:Loaded checkpoint 'pretrained_models/azusa/azusa.pth' (iteration 1112)
# INFO:root:Loaded checkpoint 'pretrained_models/alice/alice.pth' (iteration 1143)
# INFO:root:Loaded checkpoint 'pretrained_models/shiroko/shiroko.pth' (iteration 1251)
# INFO:root:Loaded checkpoint 'pretrained_models/hina/hina.pth' (iteration 801)
# INFO:root:Loaded checkpoint 'pretrained_models/iori/iori.pth' (iteration 901)
# INFO:root:Loaded checkpoint 'pretrained_models/izuna/izuna.pth' (iteration 1223)
# INFO:root:Loaded checkpoint 'pretrained_models/yuuka/yuuka.pth' (iteration 1751)
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): checkip.amazonaws.com:443
# DEBUG:urllib3.connectionpool:https://checkip.amazonaws.com:443 "GET / HTTP/1.1" 200 14
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.gradio.app:443
# DEBUG:urllib3.connectionpool:https://api.gradio.app:443 "POST /gradio-initiated-analytics/ HTTP/1.1" 200 None
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 9, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 9, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 9, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 9, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 9, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 9, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 9, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=0,level=0,tokens=0), 0, 9, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=1,level=0,tokens=3), 1, 9, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=1,level=0,tokens=3), 1, 9, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=1,level=0,tokens=3), 1, 9, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=1,level=0,tokens=3), 1, 9, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=1,level=0,tokens=3), 1, 9, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=1,level=0,tokens=3), 1, 9, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=1,level=0,tokens=3), 1, 9, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=1,level=0,tokens=3), 1, 9, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=2,level=0,tokens=6), 2, 9, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=2,level=0,tokens=6), 2, 9, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=2,level=0,tokens=6), 2, 9, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=2,level=0,tokens=6), 2, 9, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=2,level=0,tokens=6), 2, 9, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=2,level=0,tokens=6), 2, 9, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=2,level=0,tokens=6), 2, 9, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=2,level=0,tokens=6), 2, 9, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=4,level=0,tokens=9), 4, 9, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=4,level=0,tokens=9), 4, 9, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=4,level=0,tokens=9), 4, 9, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=4,level=0,tokens=9), 4, 9, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=4,level=0,tokens=9), 4, 9, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=4,level=0,tokens=9), 4, 9, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=4,level=0,tokens=9), 4, 9, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=4,level=0,tokens=9), 4, 9, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=4,level=0,tokens=9), 4, 9, False
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=4,level=0,tokens=9), 4, 9, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=6,level=0,tokens=12), 6, 9, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=6,level=0,tokens=12), 6, 9, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=6,level=0,tokens=12), 6, 9, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=6,level=0,tokens=12), 6, 9, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=6,level=0,tokens=12), 6, 9, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=6,level=0,tokens=12), 6, 9, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=6,level=0,tokens=12), 6, 9, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=6,level=0,tokens=12), 6, 9, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=6,level=0,tokens=12), 6, 9, False
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=6,level=0,tokens=12), 6, 9, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=8,level=0,tokens=15), 8, 9, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=8,level=0,tokens=15), 8, 9, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=8,level=0,tokens=15), 8, 9, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=8,level=0,tokens=15), 8, 9, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=8,level=0,tokens=15), 8, 9, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=8,level=0,tokens=15), 8, 9, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=8,level=0,tokens=15), 8, 9, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=8,level=0,tokens=15), 8, 9, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=8,level=0,tokens=15), 8, 9, False
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=8,level=0,tokens=15), 8, 9, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 1, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 6, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 6, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 6, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 6, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 6, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 6, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 6, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 6, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 6, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 6, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 6, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 6, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 6, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 6, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 6, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 6, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 6, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 6, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 6, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 6, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 6, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 6, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 6, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 6, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 6, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 6, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 6, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 6, False
# DEBUG:asyncio:Using selector: SelectSelector
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 127.0.0.1:7860
# DEBUG:urllib3.connectionpool:http://127.0.0.1:7860 "GET /startup-events HTTP/1.1" 200 4
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 127.0.0.1:7860
# DEBUG:urllib3.connectionpool:http://127.0.0.1:7860 "HEAD / HTTP/1.1" 200 0
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.gradio.app:443
# DEBUG:urllib3.connectionpool:https://api.gradio.app:443 "POST /gradio-launched-analytics/ HTTP/1.1" 200 None

# %%
target_model = None
for model in models:
    _, name_en, _, _, _, _, _, net_g_ms, _, _ = model
    if name_en == "Shirasu Azusa":
        target_model = net_g_ms
        break

# 先创建tts函数
tts_fn = create_tts_fn(net_g_ms, 10)

# 再创建to_symbol函数
to_symbol_fn = create_to_symbol_fn(hps_ms)

# 设置输入参数
#text = "はぁぁぁ……はぁぁぁ……"
#text = "ちゅる……んっ……はぁぁ……んちゅん……はぁぁ……はぁぁ……"
#text = "んん……んん……"
text = "はひ、ふひっ、あはっ…あはぁ…はぁはぁ…んは…"
language = 1  # 可以是0（中文），1（日语），或者2（中日混合）
noise_scale = 0.5  # 控制感情变化程度
noise_scale_w = 0.68  # 控制音素发音长度
length_scale = 1.2  # 控制整体语速
is_symbol = False  # 符号输入

# 生成音频
message, audio_data = tts_fn(text, language, noise_scale, noise_scale_w, length_scale, is_symbol)

# 打印生成消息
print(message)

# 保存生成的音频
import IPython.display as ipd

sample_rate, audio = audio_data
ipd.display(ipd.Audio(audio, rate=sample_rate, normalize=False))
# Out:
# Success
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import os
import re
import torch
import IPython.display as ipd
import soundfile as sf

def save_wav(file_path, audio, sample_rate):
    sf.write(file_path, audio, sample_rate, 'PCM_16')

# 确定设备：如果有可用的GPU，则使用GPU；否则使用CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# 创建保存音频的目录
output_dir = "D:/KKVITS"
os.makedirs(output_dir, exist_ok=True)

# 设置模型和说话者ID
target_model = None
for model in models:
    _, name_en, _, _, _, _, _, net_g_ms, _, _ = model
    if name_en == "Shirasu Azusa":
        target_model = net_g_ms.to(device)  # Move the model to the chosen device
        break

# 创建tts函数
tts_fn = create_tts_fn(target_model, speaker_id)

# 创建to_symbol函数
to_symbol_fn = create_to_symbol_fn(hps_ms)

# 遍历文本数据集
with open("C:\\Users\\Skywalker\\Desktop\\推理集1\\c29直率冷漠_output.txt", "r", encoding="utf-8") as file:
    lines = file.readlines()

for line in lines:
    line = line.strip()
    if not line:
        continue
    
    # 解析文件名和文本内容
    match = re.match(r"(.*?)\|(.*)", line)
    if match:
        file_name = match.group(1)
        text = match.group(2)

        # 生成音频
        language = 1  # 可以是0（中文），1（日语），或者2（中日混合）
        noise_scale = 0.6  # 控制感情变化程度
        noise_scale_w = 0.668  # 控制音素发音长度
        length_scale = 1  # 控制整体语速
        is_symbol = False  # 符号输入

        message, audio_data = tts_fn(text, language, noise_scale, noise_scale_w, length_scale, is_symbol)

        # 打印生成消息
        print(message)

        # 保存生成的音频
        file_path = os.path.join(output_dir, f"{file_name}.wav")
        sample_rate, audio = audio_data
        save_wav(file_path, audio, sample_rate)
